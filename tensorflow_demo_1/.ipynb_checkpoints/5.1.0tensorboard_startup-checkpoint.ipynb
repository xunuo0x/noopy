# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 载入数据集
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# 每个批次的大小
batch_size = 100

# 计算一共多少个batch
n_batch = mnist.train.num_examples // batch_size

# 参数概要
def variable_summaries(var):
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev) # 标准差
        tf.summary.scalar('max', tf.reduce_max(var)) # 最大值
        tf.summary.scalar('min', tf.reduce_min(var)) # 最小值
        tf.summary.histogram('histogram', var) # 直方图

# 命名空间
with tf.name_scope('input'):
    # 定义两个placeholder
    x = tf.placeholder(tf.float32, [None, 784], 'x-input')
    y = tf.placeholder(tf.float32, [None, 10], 'y-input')
keep_prob = tf.placeholder(tf.float32)

with tf.name_scope('layer'):
    # 创建一个简单的神经网络
    with tf.name_scope('weight'):
        W = tf.Variable(tf.zeros([784, 10]), name='W')
        variable_summaries(W)
    with tf.name_scope('bias'):
        b = tf.Variable(tf.zeros([10]), name='b')
        variable_summaries(b)
    with tf.name_scope('wx_plus_b'):
        wx_plus_b = tf.matmul(x, W) + b
    with tf.name_scope('softmax'):
        prediction = tf.nn.softmax(wx_plus_b)

# 二次代价函数
#loss = tf.reduce_mean(tf.square(y-prediction))
# 交叉熵代价函数
with tf.name_scope('loss'):
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))
    tf.summary.scalar('loss', loss)
    
# 优化器：使用梯度下降法
with tf.name_scope('train'):
    train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
# train_step = tf.train.(lr).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
        # 预测准确率
        correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction, 1))
    with tf.name_scope('accuracy'):
        # 计算准确率
        accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
        tf.summary.scalar('accuracy', accuracy)

# 合并所有的summary
merged = tf.summary.merge_all()
        
with tf.Session() as sess:
    sess.run(init)
    writer = tf.summary.FileWriter('logs/5.1.0/',sess.graph)
    for epoch in range(51):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            summary,_ = sess.run([merged,train_step], feed_dict={x: batch_xs, y:batch_ys, keep_prob: 1.0})
        
        writer.add_summary(summary, epoch)
        test_acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y:mnist.test.labels})
        train_acc = sess.run(accuracy, feed_dict={x: mnist.train.images, y:mnist.train.labels})
        print('Iter ' + str(epoch) + ',Testing Accuracy '+ str(test_acc) + ' ,Traing Accuracy '+ str(train_acc))
# Out:
# WARNING:tensorflow:From <ipython-input-2-9d30be45c9ce>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From D:\IDE\Miniconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From D:\IDE\Miniconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From D:\IDE\Miniconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\IDE\Miniconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\IDE\Miniconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-2-9d30be45c9ce>:46: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Iter 0,Testing Accuracy 0.825 ,Traing Accuracy 0.8143455
# Iter 1,Testing Accuracy 0.8915 ,Traing Accuracy 0.88363636
# Iter 2,Testing Accuracy 0.9017 ,Traing Accuracy 0.8946364
# Iter 3,Testing Accuracy 0.9042 ,Traing Accuracy 0.8992364
# Iter 4,Testing Accuracy 0.9088 ,Traing Accuracy 0.90238184
# Iter 5,Testing Accuracy 0.9111 ,Traing Accuracy 0.9050364
# Iter 6,Testing Accuracy 0.9117 ,Traing Accuracy 0.90745455
# Iter 7,Testing Accuracy 0.9127 ,Traing Accuracy 0.90885454
# Iter 8,Testing Accuracy 0.9147 ,Traing Accuracy 0.9108727
# Iter 9,Testing Accuracy 0.916 ,Traing Accuracy 0.9117636
# Iter 10,Testing Accuracy 0.9168 ,Traing Accuracy 0.91312724
# Iter 11,Testing Accuracy 0.9189 ,Traing Accuracy 0.9133818
# Iter 12,Testing Accuracy 0.9182 ,Traing Accuracy 0.91458184
# Iter 13,Testing Accuracy 0.9185 ,Traing Accuracy 0.91525453
# Iter 14,Testing Accuracy 0.92 ,Traing Accuracy 0.9162727
# Iter 15,Testing Accuracy 0.9206 ,Traing Accuracy 0.9169273
# Iter 16,Testing Accuracy 0.9217 ,Traing Accuracy 0.9173818
# Iter 17,Testing Accuracy 0.9214 ,Traing Accuracy 0.9180909
# Iter 18,Testing Accuracy 0.9208 ,Traing Accuracy 0.9186364
# Iter 19,Testing Accuracy 0.9207 ,Traing Accuracy 0.919
# Iter 20,Testing Accuracy 0.9218 ,Traing Accuracy 0.9195273
# Iter 21,Testing Accuracy 0.9219 ,Traing Accuracy 0.9198727
# Iter 22,Testing Accuracy 0.9221 ,Traing Accuracy 0.9200182
# Iter 23,Testing Accuracy 0.9228 ,Traing Accuracy 0.9210727
# Iter 24,Testing Accuracy 0.9226 ,Traing Accuracy 0.92112726
# Iter 25,Testing Accuracy 0.9234 ,Traing Accuracy 0.9219273
# Iter 26,Testing Accuracy 0.9239 ,Traing Accuracy 0.9222
# Iter 27,Testing Accuracy 0.9239 ,Traing Accuracy 0.9223273
# Iter 28,Testing Accuracy 0.9242 ,Traing Accuracy 0.9226909
# Iter 29,Testing Accuracy 0.9235 ,Traing Accuracy 0.92265457
# Iter 30,Testing Accuracy 0.9236 ,Traing Accuracy 0.9232909
# Iter 31,Testing Accuracy 0.9248 ,Traing Accuracy 0.9233818
# Iter 32,Testing Accuracy 0.924 ,Traing Accuracy 0.9236909
# Iter 33,Testing Accuracy 0.9247 ,Traing Accuracy 0.9237818
# Iter 34,Testing Accuracy 0.9262 ,Traing Accuracy 0.9240182
# Iter 35,Testing Accuracy 0.9254 ,Traing Accuracy 0.9247091
# Iter 36,Testing Accuracy 0.9248 ,Traing Accuracy 0.92481816
# Iter 37,Testing Accuracy 0.9243 ,Traing Accuracy 0.9250364
# Iter 38,Testing Accuracy 0.9254 ,Traing Accuracy 0.92496365
# Iter 39,Testing Accuracy 0.9261 ,Traing Accuracy 0.92521816
# Iter 40,Testing Accuracy 0.9254 ,Traing Accuracy 0.92554545
# Iter 41,Testing Accuracy 0.9261 ,Traing Accuracy 0.92585456
# Iter 42,Testing Accuracy 0.9261 ,Traing Accuracy 0.9260727
# Iter 43,Testing Accuracy 0.9261 ,Traing Accuracy 0.92603636
# Iter 44,Testing Accuracy 0.9255 ,Traing Accuracy 0.9262546
# Iter 45,Testing Accuracy 0.9265 ,Traing Accuracy 0.9266
# Iter 46,Testing Accuracy 0.9259 ,Traing Accuracy 0.9268364
# Iter 47,Testing Accuracy 0.9264 ,Traing Accuracy 0.9269091
# Iter 48,Testing Accuracy 0.9265 ,Traing Accuracy 0.92716366
# Iter 49,Testing Accuracy 0.9262 ,Traing Accuracy 0.9273091
# Iter 50,Testing Accuracy 0.9276 ,Traing Accuracy 0.92752725
